# %% [markdown]
# Let's review [Python Basics](https://colab.research.google.com/drive/1vklSCiRclBri5ghIcavk2J2sCEX3UVf8?usp=sharing&fbclid=IwAR1RPZTOjaOFvfOVRqG8nFtdpw5SOiV_R4KF3yVATo-QtpeMd9JM7y0FMhQ)

# %%
#!pip install --upgrade -q pygsheets
# !pip install xlrd
# Out:
# Collecting xlrd
#   Downloading xlrd-1.2.0-py2.py3-none-any.whl (103 kB)
# Installing collected packages: xlrd
# Successfully installed xlrd-1.2.0

# %%
#import google.auth
#from google.colab import auth
#auth.authenticate_user() #access google
#import pygsheets #read googlesheet
import pandas as pd #manage excel like data
import numpy as np #manage numerical data
import seaborn as sns #plot
import matplotlib.pyplot as plt #plot

# %%
credentials, _ = google.auth.default()
gc = pygsheets.client.Client(credentials)

# %%
#sheet = gc.open_by_url('https://docs.google.com/spreadsheets/d/1cizxcN0EyYJDrX-o04Ptwd6XQUxnJNfmrFgxeVNfgJo/edit?usp=sharing')

# %%
dat = pd.read_excel('botnoixshopee_data.xlsx', sheet_name='Sheet1')
dat = dat.dropna() #get rid of NaN
dat
# Out:
#                   Timestamp Title   Age Citizenship Rate your skills [Python]  \
# 1   2020-07-01 15:21:41.000   Mr.  23.0   Singapore    Have used in a project
# 2   2020-07-01 15:38:09.000   Ms.  25.0      Taiwai              Have studied
# 3   2020-07-01 15:38:59.000   Mr.  18.0   Singapore             No Background
# 4   2020-07-01 15:41:46.000   Ms.  40.0    Malaysia             No Background
# 5   2020-07-01 15:47:54.000   Mr.  23.0   Singapore              Have studied
# ..                      ...   ...   ...         ...                       ...
# 539 2020-07-05 16:07:18.809   Mr.  21.0    Malaysia             No Background
# 540 2020-07-05 18:04:25.018   Ms.  30.0   Indonesia    Have used in a project
# 541 2020-07-05 20:57:20.721   Ms.  21.0   Singapore              Have studied
# 542 2020-07-06 07:43:48.791   Mr.  13.0   Singapore    Have used in a project
# 543 2020-07-06 08:55:17.539   Mr.  22.0   Singapore              Have studied
#
#     Rate your skills [Machine learning]  \
# 1                         No Background
# 2                         No Background
# 3                         No Background
# 4                         No Background
# 5                          Have studied
# ..                                  ...
# 539                       No Background
# 540              Have used in a project
# 541              Have used in a project
# 542                        Have studied
# 543                       No Background
#
#     What is your expectation from attending this class?  \
# 1                                       to gain skills
# 2                 get the knowledge about data science
# 3                            Able to understand python
# 4                                 Clear about the role
# 5         Learn more about python and machine learning
# ..                                                 ...
# 539           To learn how to write scripts in python
# 540                      Learn python for data science
# 541  Knowing more about Python and Numpy for data t...
# 542                                                  -
# 543         learn more about how python is used for ds
#
#     What is your best favorite category to purchase online?  \
# 1                                           Men's Wear
# 2                               Beauty & Personal Care
# 3                              Computers & Peripherals
# 4                                     Food & Beverages
# 5                                     Food & Beverages
# ..                                                 ...
# 539                                         Men's Wear
# 540                                   Food & Beverages
# 541                                    Women's Apparel
# 542                            Computers & Peripherals
# 543                                    Hobbies & Books
#
#     What is your second favorite category to purchase online?  \
# 1                                      Hobbies & Books
# 2                                      Women's Apparel
# 3                                     Mobile & Gadgets
# 4                                          Video Games
# 5                                          Video Games
# ..                                                 ...
# 539                                    Hobbies & Books
# 540                             Beauty & Personal Care
# 541                             Beauty & Personal Care
# 542                                         Men's Wear
# 543                                         Men's Wear
#
#     What is you third favorite category to purchase online?
# 1                              Computers & Peripherals
# 2                                     Food & Beverages
# 3                                          Video Games
# 4                              Jewellery & Accessories
# 5                                           Men's Wear
# ..                                                 ...
# 539                                   Food & Beverages
# 540                                    Hobbies & Books
# 541                                   Mobile & Gadgets
# 542                                   Mobile & Gadgets
# 543                                   Food & Beverages
#
# [541 rows x 10 columns]

# %%
dat.columns
# Out:
# Index(['Timestamp', 'Title', 'Age', 'Citizenship', 'Rate your skills [Python]',
#        'Rate your skills [Machine learning]',
#        'What is your expectation from attending this class?',
#        'What is your best favorite category to purchase online?',
#        'What is your second favorite category to purchase online?',
#        'What is you third favorite category to purchase online?'],
#       dtype='object')

# %%
newcol = ['Timestamp', 'Title', 'Age', 'Citizen', 'PythonSkill','MLSkill','Expectation','Fav1','Fav2','Fav3']

# %%
dat.columns = newcol

# %% [markdown]
# # Expectation

# %%
textList = dat['Expectation'].values
#textList
textList[0]
# Out:
# array(['to gain skills', 'get the knowledge about data science',
#        'Able to understand python', 'Clear about the role',
#        'Learn more about python and machine learning',
#        'Learn more useful functions in Python.',
#        'More experience in machine learning using python',
#        'Skillup for python', 'Basics and Fundamentals of Python',
#        'To get a preliminary understanding of Python and its use in Data Science (e.g. Why particularly Python over other programming languages that makes it so special for data science and ML?)',
#        'To learn more', 'Some knowledge',
#        'Prepare for Shopee competition', 'To learn basic python',
#        'Know more with Machine Learning',
#        'I want to influence my self and learn something different from my class at university.',
#        'To learn and reinforce fundamentals',
#        'I will be able to master Python for Data Science since I am eagerly to learn it to do some projects given by my college and I hope I can learn it furthermore to make it as part of my career in the future',
#        'Learn more python', 'To learn more abt python', '-', 'Learn',
#        'Learn and apply', 'Learn',
#        'A beginner-friendly Data Science class.',
#        'Learn more about python',
#        'Will have a general overview about Python and its uses.',
#        'to gain knowledge regarding the given theme and apply it for future study or projects.',
#        'I will learn',
#        'know how to code with python for machine learning',
#        'Basic introduction of python and ML',
#        'I can familiar with Python',
#        'To improve my knowledge about Python since I am still at beginner level.',
#        'learn the tensorflow/keras command and preprare data for training',
#        '.', 'Not basic syntax, but will learn something new',
#        'Understand Data Science coding using Python', 'Pro',
#        'Practice coding in Python', 'i can understand more about python',
#        'I hope to learn more from this course',
#        'I hope to gain more knowledge in python',
#        'To gain some knowledge about the Phytonn and machine language',
#        'How to use python in machine learning',
#        'With this training.. I hope all attendants can be more familiar with Python',
#        'Add my experience about logic and programming',
#        'i learn something new about python and machine learning',
#        'Learning Example in real world',
#        'Gain more knowledge about Python so I can use it for my future projects.',
#        'Learning example in real world',
#        'To be more familiar in using data science concepts to solve real world problems and provide solution from a consulting stand point.',
#        'learn python', 'Learn the basics of Python',
#        'know how to use Python', 'Learning something new',
#        'Supplement my knowledge in python', 'Learn more about DS',
#        'to learn about python usage in data science',
#        "Being able to implement what I've learned in the class to small projects or as a foundation for future learning",
#        'For practice and familiarization', 'NIL',
#        'Be able to code in python for data science', 'Python Refresher',
#        'Learn more about Python to use in data science field',
#        'Improve Python', 'no expectations. will absorb all.',
#        'learn to use python in a project',
#        'Learning functions and have a deeper understanding in loops and variables.',
#        'Learning essential feature in python',
#        'Have a deep understanding of data science',
#        'I can improve my skill', 'know how to apply python',
#        'Enhance knowledge in python', 'To apply coding',
#        'Mastering Python even more', 'Can gain some inspects',
#        'Understanding and knowledge especially about python for data science.',
#        'to have some experience and knowledge', 'know the material',
#        'theory and application to real world problems',
#        'live coding, more and more practice, description',
#        'learning python',
#        'To learn more about python and machine learning',
#        'Become more familiar with python', 'gain more knowledge',
#        'Gain a more efficient way of handling data compared to what i currently know',
#        'intermidiat python',
#        'Learn how to incorporate python in Machine learning',
#        'learn basic data science skill',
#        'I will increase my basic skill in data science with python',
#        'Learn how to use bot', 'to learn about python in data science',
#        'just refresh on fundamentals', 'to do well in machine learning',
#        'Knowledge on the fundamentals of the language to use from a Data Science perspective',
#        'To learn the practical use of data science and machine learning',
#        'I expect to understand everything related to this class.',
#        'More understand about python for data science',
#        'Learn new techniques', 'No expectation', 'Understanding Python',
#        'learn and gain experience\nabout python and machine learning',
#        'I want to be able to use python more efficiently.',
#        'Learning more about using python for data science purposes',
#        'To learn more about Python in Data science', 'Basic Python',
#        'Have a basic foundation about machine learning',
#        'learning some basics on python',
#        'Learn Python programming language',
#        'able to implement phyton in machine learning',
#        'Learn more about real world python applications',
#        'Learn something new', 'Nil',
#        "To have a deeper understanding in Python! Because I've only learnt about Python but now how it can be used in Data Science",
#        'Learning the basics to be able to do something',
#        'Improving my knowledge in Python',
#        'getting to know more about machine learning advanced fundamentals',
#        'get to know more about python',
#        'Gain a better knowledge about looping after the class', '-',
#        'Know more about Python and ML',
#        'understand how to use loop and condition better in phyton',
#        'learn python in data science',
#        'Get more familiarized with Python writeups',
#        'learn data science using python', 'Clear notes and teaching',
#        'learn the fundamentals', 'using python for data science',
#        'To be able to code using python in breeze.',
#        'My expectation is to understand more about python and data science.',
#        'Know more about Python',
#        'More things about ML. More data processing knowledge is better.',
#        'Easy to follow instructions and slides',
#        'Learn fundamentals of Python, and hope use these basics to prepare for the more  advanced courses',
#        'Learn more about data science', 'learn some basics about Python',
#        'learn how to detect human in photo',
#        'I hope to learn how python is applied in data science',
#        'Learn python',
#        'Learn more about python and its usage in the area of Data science.',
#        'Learn more about Data Science', 'Can do programming in python',
#        'Gain technical know-how on using libraries like scikit learn or others to create machine learning models.',
#        'Nothing', 'Learn  and practice new knowledge',
#        'get to kow python data science better',
#        'Something new, especially for ML usage',
#        'As a revision for python syntax',
#        'Learn and develop something new',
#        'Learn things useful for class, easy to follow', 'Knowledge', 'na',
#        'Get some exposure', 'Learning something new about python',
#        'To learn how to use coding knowledge in data science',
#        'Learn some basic Python skills',
#        'More understanding and able to adapt with the project or working in the future',
#        'Able to learn something new', 'Learn basic coding',
#        'Know more about this topic', 'not sure', '-',
#        'Have a deeper knowledge about Python and able to utilise it more efficiently',
#        'Learning more indepth integration of machine learning and computer vision for projects that I am working on',
#        'to improve skill and knowledge in data science',
#        'Better understanding', 'Learn, and receive some materials',
#        'More python skills', 'Learn something',
#        'to learn more about the usage of python and machine learning as im interested in it',
#        'To learn',
#        'How to build an image classification model in Python?',
#        'Familiarise with python and gain some basic knowledge about data science',
#        'Learn anything', 'To be pro in pandas and numpy',
#        'Solidify my fundamentals and confidence to work on future projects',
#        'The training is appropriate for beginner',
#        'Boosting python skills',
#        'Useful technique of python in data science', 'Practical skills',
#        'Build up on my python skills for Data science',
#        'Learn how to make models',
#        'To learn how to write scripts from a data science perspective, and learn more about how Python is used in Data science',
#        'Knowledge',
#        'learn how to use python in practical cases and works',
#        'Learn to use python for machine learning.',
#        'Strengthen Python fundamental', 'Refreshing the fundamental',
#        'get to know better understanding to machine learning',
#        'Allows me to better understand data science',
#        'To understand how Python is being used for data science, what are the associated libraries to use etc',
#        'Learn',
#        'To learn about current trends in Python programming for Data Science',
#        'Learn from basic', 'Practical examples', 'learn python',
#        'Understanding more of python', 'Learn skills to apply job',
#        'Hone python skills', 'To understand the fundamental of python',
#        'I want to understand data science using python',
#        'learn more understanding about the topic',
#        'Can have your own bot and can do another thing using these skills',
#        'Introduction and learning of python and data science basics to enhance future learning',
#        'Create Chatbot', 'studying from fundamental',
#        'To be able to apply data science into projects by learning the fundamentals of machine learning and working with data to bring about a useful and valuable analysis',
#        'More understand', 'Able to understand the basics',
#        'knowing how to use python for data science', 'Exposure',
#        'get better understanding python in data science project',
#        'Learning Basics',
#        'To learn the basics of data science and how to use python in performing data science problems',
#        'It’s useful',
#        'I wish I can be an advanced python programmer, and I can develop something interesting.',
#        'learn as much as i can', 'Learning python',
#        'learn the basic of both python and machine learning. Maybe get an insider of the company to have better understanding of the background of the industry',
#        'I can learn more about python', 'I like it', 'learn',
#        'I get knowledge about data scientist with python',
#        "I'm hoping that I could understand the python fundamentals.",
#        'Understand basic functions on machine learning and how to use them',
#        'I can get more knowledge about data science, get more hands-on in the course',
#        'I get information , knowledge and insight',
#        'Learn useful things in a suitable pace',
#        'learn sth new about python', 'Learn something new',
#        'To learn a more about python and understand it better.',
#        'refresh my basic python skills',
#        'Get knowledge of machine learning', 'Shopee code league',
#        'Learn something new', 'Learning Python for Data Science',
#        'To know more about Python and how to handle it',
#        'To gain more skills and knowledge with regards to data science',
#        'Discover the important tools in python for data science',
#        'case study', 'Learn python', 'Learn python',
#        'to review my python programming skill', '\nDetailed teaching',
#        'Keep practicing writing scripts with loops, functions, etc.',
#        'Learning how python is used in Database aspect',
#        'To learn more and have a wonderful experience while learning.',
#        'learn how to use python to deal with data',
#        'Gain practical skills',
#        'I want to know phyton and can operate it',
#        'get more information and knowledge about data science with python',
#        '基礎運用', 'Learn about more code knowledge', '.',
#        'Start learning about Phyton and Machine Learning',
#        'learning python to do research and analytics',
#        'Some basics on how to use machine learning.',
#        'To learn the basics of python for data science',
#        'To gain knowledge on top of my interest in learning python',
#        'To learn how to use Python is data science use cases',
#        'more understand using machine learning in real case',
#        'To learn something useful', 'Get used to it',
#        'To be able understand more about machine learning',
#        'How to apply skill in real world',
#        'find back my interest in machine learning',
#        'Learning Data Analysis',
#        'Broaden my limited scope of understanding of the usage for python',
#        'Gain further understanding of python programming and how to apply it to data science',
#        'Hope to brush up/pick up new skills',
#        'Improve understanding of Python', 'learn new things',
#        'improve python skills', 'Learn', 'Know more Data Science',
#        'Just curiosity',
#        'Able to understand the principle and structure of the language.',
#        'Deepen my knowledge to the software',
#        'learn important algorithms in Python for data analysis', '-',
#        'Learn',
#        'with my limited amount of knowledge (from doing online lessons), i would like to learn as much as i can',
#        'Learning', 'Learning how to code with Python.',
#        'Python fundamental for Data Science',
#        'to have more understanding and practical use of python',
#        'master in settling problem by using algorithm',
#        'Better in using python and learn more about data science',
#        'to review my python programming skill',
#        'I would be able to more fluently use python and its libraries to conduct data science projects, machine learning et cetera',
#        'Learn more on Data Science using Python',
#        'To gain new knowlege and improve my coding skill',
#        'learn something new', 'have the basics to learn data science',
#        'To learn the basics of python', 'Gain basic skill in Python',
#        'Learn something', 'To know more about coding',
#        'Learn more about machine learning with python',
#        'To gain more knowledge about machine learning',
#        'More experience in python', 'nothing really',
#        'Strengthening the knowledge on the basics of Python programming in order to develop effective, useful, and versatile Python skills that will be applicable in various cases',
#        'Learn more about python for data science',
#        'More expert in Python', 'Better understanding on AI practices',
#        'To learn more', 'Leveling up my python skill',
#        'data science insights',
#        'Good level of understanding of using python',
#        'Learn more about ML',
#        'To learn more about machine learning and how to apply it',
#        'Get introduced into the Python for data science and be familiar with the jargon used.',
#        'Brush up basic skills and have an idea how Python is used in Data Science',
#        'Learn about how Data science are used practically',
#        'Build basic understanding for data science.',
#        'I will learn more about machine learning using python',
#        'Learn basics of python', 'NIL',
#        'Able To Use Python to do Data Science related projects',
#        'learn something new',
#        'I hope to get more ideas and methods of unsupervised AI and machine learning using python',
#        'I will get many insight here and improve my skill to solve the problem',
#        'To understand more about machine learning and getting more relation with anyone with the same enthusiast because i think that i still need much things to learn about python fundamental as much as machine learning advance issues',
#        'To learn as much as possible',
#        'can apply something to other stuff',
#        'Know more about using python for data science',
#        'To be beginner  friendly', 'Get some experience',
#        'I want to learn the fundamental python skills because I learned python on my own and have no solid fundation. I have been interested in learning machine learning for a long time, so I’m looking forward to join this workshop.',
#        'learn as much as i can',
#        'Get a solid learning path and resources',
#        'Learn python for Shoppe competition',
#        'know more about data science',
#        'Learn python for Shoppe competition',
#        'I hope I Get to know complete structure of coding in Python',
#        'To have a better understanding of python for data science',
#        'Some hands-on exercises to apply new tools',
#        'know more about data science', 'to gain skills',
#        'Learn more about pandas and numpy', 'Skillup in pandas',
#        'Some knowledge', 'Understand more about Numpy and Pandas',
#        'More lessons about python',
#        'To learn more about python after attending the first python class.',
#        'Know more with Machine Learning',
#        'I want to improve my self and develop my programming skill especially Python further',
#        'To learn and reinforce fundamentals ',
#        'Would like to understand more about machine learning ',
#        'I could Upgrade my skill in Data science with Python since I am a totally beginner in it so that I can strengthen my basic in it. ',
#        '-', 'More in-depth of python after part 1', 'Learn',
#        'Learn and apply', 'Tips and tricks', 'I will learn about Python.',
#        'gain more information on python', 'I will learn',
#        'I can familiar with Python', 'To improve my Python knowledge. ',
#        'Learning more about Numpy',
#        'data science advance like how different layer of neural network works',
#        '.', 'Learning something that can get me started on NLP',
#        'Understand Data Science',
#        'Practice using function in pandas and numpy', 'Learn about DS',
#        "Being able to implement what I've learned in the class to small projects or as a foundation for future learning",
#        'Learn more about numpy', 'NIL',
#        'Learn more data science use cases', 'Python Refresher',
#        'can use python in a project',
#        'Understand the basic of using Pandas and Numpy',
#        'Learning numpy! ', 'Improve my knowledge on data science',
#        'Understand data science better ',
#        'have a concept on python language and machine learning',
#        'I can improve my skill', 'Upskill python',
#        'Mastering Python even more', 'Knowledge', 'knowing the material',
#        'solving real world problems', 'learning python',
#        'To learn more about python and machine learning',
#        'Become more familiar with Python ', 'Learning ',
#        'I will increase my data science skill after attending module 1 and this course',
#        'Learn more about bot',
#        'to learn about python use in data science',
#        'Learn more about data science knowledge',
#        'To learn the practical use of data science and machine learning',
#        'I expect to fully understand the materials related.',
#        'I expect to fully understand the materials related.',
#        'Gain better understanding in the use of pandas and numpy in python for data sci',
#        'To learn data science.',
#        'learn and gain experience\nabout python and machine learning',
#        'I want to be able to use python more efficiently.',
#        'Learning more about python for data science purposes',
#        'How to use Numpy and Pandas', 'learning new things about python',
#        'Learn about real world applications of python',
#        'Learn something new', 'nil', 'Learn more about python!',
#        'To be able to apply on a basic foundation',
#        'Getting to know better how to use pandas and numpy as efficient as possible',
#        'know more about python', '-', 'Understand numpy and pandas',
#        'How to use pandas and numpy for analyzing data',
#        'learn more computer language', 'learning data science',
#        'to learn more about ML with python',
#        'learn more about numpy and pandas', 'Able to pick up python fast',
#        'to continue studying from botnoi 1',
#        'Learn packages to help solve problems more efficiently, and know how to think in different ways ',
#        'To understand more about Python', 'more knowledge to be gajned',
#        'Learn python', 'Learning to optimise my pandas skills',
#        'gain as much knowledge as I can',
#        'Learn more about Data Science ',
#        'get to know python data science better', 'Something interesting',
#        'I can apply this with my studies',
#        'To improve my data manipulation skills in numpy and pandas',
#        'Easy to follow and learn, notes provided ', 'Get some exposure',
#        'Learn and develop something new',
#        'To learn more about how coding logic can be applied to data science ',
#        'Able to learn something new. ', '/',
#        'Know more about packages in Python and able to utilise it efficiently ',
#        'To gain more understanding about how numpys and pandas are used and applications of it in data science',
#        'More familiar with python and machine learning',
#        'Better understanding ', 'Understand the pandas and numpy library',
#        'Learn more about Python', 'More python skills',
#        'Learn more on how to use machine learning in solving everday problems.',
#        'To learn', 'Learning numpy and python',
#        'Learn more about data science',
#        'Solidify my fundamentals in python and machine learning and work on projects',
#        'Learn to code', 'Gain greater depth of knowledge ',
#        'learn anything', 'Build up python skills for data science ',
#        'To learn more about Numpy and Pandas library',
#        'learn how to use python in practical cases',
#        'Data analysis skills ',
#        'get to know better understanding to machine learning',
#        "to build upon my knowledge using Python for data science - i've signed up for part 1 conducted by BotNoi as well",
#        'Learn', 'Learn from basic', 'Practical examples',
#        'Learning some new things about Numpy and Pandas',
#        'improve my knowledge on python and ml',
#        'To understand the fundamental of python ',
#        'learn more understanding about the topic',
#        'Learn python and data science',
#        'I want to understand python using numpy and pandas for data science',
#        'To learn more about machine learning\n',
#        'Can understand the basics', 'know how to use pandas ',
#        'better understanding in python usage',
#        'I wish I can be an advanced python programmer.',
#        'learn as much as i can',
#        'To be able to improve  on my current project', 'Learning python',
#        'Learning abt numpy', 'get to understand more about data science',
#        'Be Smart', 'I get new knowledge about data scientist',
#        "I'm hoping that I can understand the basic fundamentals library in python like pandas and numpy.",
#        'get more knowledge about data science', 'Learn something new',
#        'To better understand ML using Python',
#        'refresh basic python skills', 'To have more insights',
#        'Shopee Code League ', 'Learn something new ',
#        'Numpy and Pandas in Python',
#        'gain skills and knowledge with regards to data science',
#        'to review my python programming skill',
#        "Reinforce what I've already known about Numpy and Pandas.",
#        'learning how to deal with the data using python ',
#        'Gaining Practical Skills', '基礎運用',
#        'Familiar with common use pandas and numpy libraries',
#        'learning python to do research and analytics',
#        'To use python with machine learning.',
#        'Part 2 of the first course so would like to continue learning ',
#        'learn as much as i can',
#        'to learn about functions of numpy and pandas and the syntax',
#        'Learning', 'Get used to ut', 'To learn about python.',
#        'Learn some analysis skills ',
#        'Gain further understanding in how to use python and how to apply it to data science',
#        'Hope to pick up new skills', 'Gain knowledge',
#        'Know more about  Data Science ',
#        'More understanding about principle and structure of the language. Then apply to the projects',
#        'Analyze data with python ', 'Deepen knowledge',
#        'learn as much as i can', 'Learning',
#        'Learning how to code with Python. ',
#        'Python fundamental for Data Science', 'To gain new knowledge',
#        'To learn the fundamentals of data science', 'Explore new thing',
#        'Learn more about machine learning with python',
#        'Learn more about python for data science',
#        'Hope to advance my skills', 'learn more ML ',
#        "Understand Numpy and Panda. And learn it's actual application in data science",
#        'Increase understanding about data science',
#        'I will learn how to use python for data science',
#        'Learn basics of python', 'increase knowledge',
#        'I want to learn more about data science, especially for the application of numpy and pandas library in it.',
#        'Learn a new skill that can be applied',
#        'Know more about numpy and pandas for data science ',
#        'learn as much as i can',
#        'Form a solid foundation on learning data science ',
#        'Learn immediate python', 'know more about data science',
#        'Learn immediate python',
#        'To have  a better idea in How it works in Python and data ',
#        'agility between Numpy and Pandas',
#        'To learn how to write scripts in python ',
#        'Learn python for data science',
#        'Knowing more about Python and Numpy for data transformation', '-',
#        'learn more about how python is used for ds'], dtype=object)

# %%
combinetext = ''
for text in textList:
  combinetext = combinetext + text
combinetext
# Out:
# "to gain skillsget the knowledge about data scienceAble to understand pythonClear about the roleLearn more about python and machine learningLearn more useful functions in Python.More experience in machine learning using pythonSkillup for pythonBasics and Fundamentals of PythonTo get a preliminary understanding of Python and its use in Data Science (e.g. Why particularly Python over other programming languages that makes it so special for data science and ML?)To learn moreSome knowledgePrepare for Shopee competitionTo learn basic pythonKnow more with Machine LearningI want to influence my self and learn something different from my class at university.To learn and reinforce fundamentalsI will be able to master Python for Data Science since I am eagerly to learn it to do some projects given by my college and I hope I can learn it furthermore to make it as part of my career in the futureLearn more pythonTo learn more abt python-LearnLearn and applyLearnA beginner-friendly Data Science class.Learn more about pythonWill have a general overview about Python and its uses.to gain knowledge regarding the given theme and apply it for future study or projects.I will learnknow how to code with python for machine learningBasic introduction of python and MLI can familiar with PythonTo improve my knowledge about Python since I am still at beginner level.learn the tensorflow/keras command and preprare data for training.Not basic syntax, but will learn something newUnderstand Data Science coding using PythonProPractice coding in Pythoni can understand more about pythonI hope to learn more from this courseI hope to gain more knowledge in pythonTo gain some knowledge about the Phytonn and machine languageHow to use python in machine learningWith this training.. I hope all attendants can be more familiar with PythonAdd my experience about logic and programmingi learn something new about python and machine learningLearning Example in real worldGain more knowledge about Python so I can use it for my future projects.Learning example in real worldTo be more familiar in using data science concepts to solve real world problems and provide solution from a consulting stand point.learn pythonLearn the basics of Pythonknow how to use PythonLearning something newSupplement my knowledge in pythonLearn more about DSto learn about python usage in data scienceBeing able to implement what I've learned in the class to small projects or as a foundation for future learningFor practice and familiarizationNILBe able to code in python for data sciencePython RefresherLearn more about Python to use in data science fieldImprove Pythonno expectations. will absorb all.learn to use python in a projectLearning functions and have a deeper understanding in loops and variables.Learning essential feature in pythonHave a deep understanding of data scienceI can improve my skillknow how to apply pythonEnhance knowledge in pythonTo apply codingMastering Python even moreCan gain some inspectsUnderstanding and knowledge especially about python for data science.to have some experience and knowledgeknow the materialtheory and application to real world problemslive coding, more and more practice, descriptionlearning pythonTo learn more about python and machine learningBecome more familiar with pythongain more knowledgeGain a more efficient way of handling data compared to what i currently knowintermidiat pythonLearn how to incorporate python in Machine learninglearn basic data science skillI will increase my basic skill in data science with pythonLearn how to use botto learn about python in data sciencejust refresh on fundamentalsto do well in machine learningKnowledge on the fundamentals of the language to use from a Data Science perspectiveTo learn the practical use of data science and machine learningI expect to understand everything related to this class.More understand about python for data scienceLearn new techniquesNo expectationUnderstanding Pythonlearn and gain experience\nabout  ...

# %%
textList = ''.join(textList)
textList
# Out:
# "to gain skillsget the knowledge about data scienceAble to understand pythonClear about the roleLearn more about python and machine learningLearn more useful functions in Python.More experience in machine learning using pythonSkillup for pythonBasics and Fundamentals of PythonTo get a preliminary understanding of Python and its use in Data Science (e.g. Why particularly Python over other programming languages that makes it so special for data science and ML?)To learn moreSome knowledgePrepare for Shopee competitionTo learn basic pythonKnow more with Machine LearningI want to influence my self and learn something different from my class at university.To learn and reinforce fundamentalsI will be able to master Python for Data Science since I am eagerly to learn it to do some projects given by my college and I hope I can learn it furthermore to make it as part of my career in the futureLearn more pythonTo learn more abt python-LearnLearn and applyLearnA beginner-friendly Data Science class.Learn more about pythonWill have a general overview about Python and its uses.to gain knowledge regarding the given theme and apply it for future study or projects.I will learnknow how to code with python for machine learningBasic introduction of python and MLI can familiar with PythonTo improve my knowledge about Python since I am still at beginner level.learn the tensorflow/keras command and preprare data for training.Not basic syntax, but will learn something newUnderstand Data Science coding using PythonProPractice coding in Pythoni can understand more about pythonI hope to learn more from this courseI hope to gain more knowledge in pythonTo gain some knowledge about the Phytonn and machine languageHow to use python in machine learningWith this training.. I hope all attendants can be more familiar with PythonAdd my experience about logic and programmingi learn something new about python and machine learningLearning Example in real worldGain more knowledge about Python so I can use it for my future projects.Learning example in real worldTo be more familiar in using data science concepts to solve real world problems and provide solution from a consulting stand point.learn pythonLearn the basics of Pythonknow how to use PythonLearning something newSupplement my knowledge in pythonLearn more about DSto learn about python usage in data scienceBeing able to implement what I've learned in the class to small projects or as a foundation for future learningFor practice and familiarizationNILBe able to code in python for data sciencePython RefresherLearn more about Python to use in data science fieldImprove Pythonno expectations. will absorb all.learn to use python in a projectLearning functions and have a deeper understanding in loops and variables.Learning essential feature in pythonHave a deep understanding of data scienceI can improve my skillknow how to apply pythonEnhance knowledge in pythonTo apply codingMastering Python even moreCan gain some inspectsUnderstanding and knowledge especially about python for data science.to have some experience and knowledgeknow the materialtheory and application to real world problemslive coding, more and more practice, descriptionlearning pythonTo learn more about python and machine learningBecome more familiar with pythongain more knowledgeGain a more efficient way of handling data compared to what i currently knowintermidiat pythonLearn how to incorporate python in Machine learninglearn basic data science skillI will increase my basic skill in data science with pythonLearn how to use botto learn about python in data sciencejust refresh on fundamentalsto do well in machine learningKnowledge on the fundamentals of the language to use from a Data Science perspectiveTo learn the practical use of data science and machine learningI expect to understand everything related to this class.More understand about python for data scienceLearn new techniquesNo expectationUnderstanding Pythonlearn and gain experience\nabout  ...

# %%
wordList = textList.split()
wordList
# Out:
# ['to',
#  'gain',
#  'skillsget',
#  'the',
#  'knowledge',
#  'about',
#  'data',
#  'scienceAble',
#  'to',
#  'understand',
#  'pythonClear',
#  'about',
#  'the',
#  'roleLearn',
#  'more',
#  'about',
#  'python',
#  'and',
#  'machine',
#  'learningLearn',
#  'more',
#  'useful',
#  'functions',
#  'in',
#  'Python.More',
#  'experience',
#  'in',
#  'machine',
#  'learning',
#  'using',
#  'pythonSkillup',
#  'for',
#  'pythonBasics',
#  'and',
#  'Fundamentals',
#  'of',
#  'PythonTo',
#  'get',
#  'a',
#  'preliminary',
#  'understanding',
#  'of',
#  'Python',
#  'and',
#  'its',
#  'use',
#  'in',
#  'Data',
#  'Science',
#  '(e.g.',
#  'Why',
#  'particularly',
#  'Python',
#  'over',
#  'other',
#  'programming',
#  'languages',
#  'that',
#  'makes',
#  'it',
#  'so',
#  'special',
#  'for',
#  'data',
#  'science',
#  'and',
#  'ML?)To',
#  'learn',
#  'moreSome',
#  'knowledgePrepare',
#  'for',
#  'Shopee',
#  'competitionTo',
#  'learn',
#  'basic',
#  'pythonKnow',
#  'more',
#  'with',
#  'Machine',
#  'LearningI',
#  'want',
#  'to',
#  'influence',
#  'my',
#  'self',
#  'and',
#  'learn',
#  'something',
#  'different',
#  'from',
#  'my',
#  'class',
#  'at',
#  'university.To',
#  'learn',
#  'and',
#  'reinforce',
#  'fundamentalsI',
#  'will',
#  'be',
#  'able',
#  'to',
#  'master',
#  'Python',
#  'for',
#  'Data',
#  'Science',
#  'since',
#  'I',
#  'am',
#  'eagerly',
#  'to',
#  'learn',
#  'it',
#  'to',
#  'do',
#  'some',
#  'projects',
#  'given',
#  'by',
#  'my',
#  'college',
#  'and',
#  'I',
#  'hope',
#  'I',
#  'can',
#  'learn',
#  'it',
#  'furthermore',
#  'to',
#  'make',
#  'it',
#  'as',
#  'part',
#  'of',
#  'my',
#  'career',
#  'in',
#  'the',
#  'futureLearn',
#  'more',
#  'pythonTo',
#  'learn',
#  'more',
#  'abt',
#  'python-LearnLearn',
#  'and',
#  'applyLearnA',
#  'beginner-friendly',
#  'Data',
#  'Science',
#  'class.Learn',
#  'more',
#  'about',
#  'pythonWill',
#  'have',
#  'a',
#  'general',
#  'overview',
#  'about',
#  'Python',
#  'and',
#  'its',
#  'uses.to',
#  'gain',
#  'knowledge',
#  'regarding',
#  'the',
#  'given',
#  'theme',
#  'and',
#  'apply',
#  'it',
#  'for',
#  'future',
#  'study',
#  'or',
#  'projects.I',
#  'will',
#  'learnknow',
#  'how',
#  'to',
#  'code',
#  'with',
#  'python',
#  'for',
#  'machine',
#  'learningBasic',
#  'introduction',
#  'of',
#  'python',
#  'and',
#  'MLI',
#  'can',
#  'familiar',
#  'with',
#  'PythonTo',
#  'improve',
#  'my',
#  'knowledge',
#  'about',
#  'Python',
#  'since',
#  'I',
#  'am',
#  'still',
#  'at',
#  'beginner',
#  'level.learn',
#  'the',
#  'tensorflow/keras',
#  'command',
#  'and',
#  'preprare',
#  'data',
#  'for',
#  'training.Not',
#  'basic',
#  'syntax,',
#  'but',
#  'will',
#  'learn',
#  'something',
#  'newUnderstand',
#  'Data',
#  'Science',
#  'coding',
#  'using',
#  'PythonProPractice',
#  'coding',
#  'in',
#  'Pythoni',
#  'can',
#  'understand',
#  'more',
#  'about',
#  'pythonI',
#  'hope',
#  'to',
#  'learn',
#  'more',
#  'from',
#  'this',
#  'courseI',
#  'hope',
#  'to',
#  'gain',
#  'more',
#  'knowledge',
#  'in',
#  'pythonTo',
#  'gain',
#  'some',
#  'knowledge',
#  'about',
#  'the',
#  'Phytonn',
#  'and',
#  'machine',
#  'languageHow',
#  'to',
#  'use',
#  'python',
#  'in',
#  'machine',
#  'learningWith',
#  'this',
#  'training..',
#  'I',
#  'hope',
#  'all',
#  'attendants',
#  'can',
#  'be',
#  'more',
#  'familiar',
#  'with',
#  'PythonAdd',
#  'my',
#  'experience',
#  'about',
#  'logic',
#  'and',
#  'programmingi',
#  'learn',
#  'something',
#  'new',
#  'about',
#  'python',
#  'and',
#  'machine',
#  'learningLearning',
#  'Example',
#  'in',
#  'real',
#  'worldGain',
#  'more',
#  'knowledge',
#  'about',
#  'Python',
#  'so',
#  'I',
#  'can',
#  'use',
#  'it',
#  'for',
#  'my',
#  'future',
#  'projects.Learning',
#  'example',
#  'in',
#  'real',
#  'worldTo',
#  'be',
#  'more',
#  'familiar',
#  'in',
#  'using',
#  'data',
#  'science',
#  'concepts',
#  'to',
#  'solve',
#  'real',
#  'world',
#  'problems',
#  'and',
#  'provide',
#  'solution',
#  'from',
#  'a',
#  'consulting',
#  'stand',
#  'point.learn',
#  'pythonLearn',
#  'the',
#  'basics',
#  'of',
#  'Pythonknow',
#  'how',
#  'to',
#  'use',
#  'PythonLearning',
#  'something',
#  'newSupplement',
#  'my',
#  'knowledge',
#  'in',
#  'pythonLearn',
#  'more',
#  'about',
#  'DSto',
#  'learn',
#  'about',
#  'python',
#  'usage',
#  'in',
#  'data',
#  'scienceBeing',
#  'able',
#  'to',
#  'implement',
#  'what',
#  "I've",
#  'learned',
#  'in',
#  'the',
#  'class',
#  'to',
#  'small',
#  'projects',
#  'or',
#  'as',
#  'a',
#  'foundation',
#  'for',
#  'future',
#  'learningFor',
#  'practice',
#  'and',
#  'familiarizationNILBe',
#  'able',
#  'to',
#  'code',
#  'in',
#  'python',
#  'for',
#  'data',
#  'sciencePython',
#  'RefresherLearn',
#  'more',
#  'about',
#  'Python',
#  'to',
#  'use',
#  'in',
#  'data',
#  'science',
#  'fieldImprove',
#  'Pythonno',
#  'expectations.',
#  'will',
#  'absorb',
#  'all.learn',
#  'to',
#  'use',
#  'python',
#  'in',
#  'a',
#  'projectLearning',
#  'functions',
#  'and',
#  'have',
#  'a',
#  'deeper',
#  'understanding',
#  'in',
#  'loops',
#  'and',
#  'variables.Learning',
#  'essential',
#  'feature',
#  'in',
#  'pythonHave',
#  'a',
#  'deep',
#  'understanding',
#  'of',
#  'data',
#  'scienceI',
#  'can',
#  'improve',
#  'my',
#  'skillknow',
#  'how',
#  'to',
#  'apply',
#  'pythonEnhance',
#  'knowledge',
#  'in',
#  'pythonTo',
#  'apply',
#  'codingMastering',
#  'Python',
#  'even',
#  'moreCan',
#  'gain',
#  'some',
#  'inspectsUnderstanding',
#  'and',
#  'knowledge',
#  'especially',
#  'about',
#  'python',
#  'for',
#  'data',
#  'science.to',
#  'have',
#  'some',
#  'experience',
#  'and',
#  'knowledgeknow',
#  'the',
#  'materialtheory',
#  'and',
#  'application',
#  'to',
#  'real',
#  'world',
#  'problemslive',
#  'coding,',
#  'more',
#  'and',
#  'more',
#  'practice,',
#  'descriptionlearning',
#  'pythonTo',
#  'learn',
#  'more',
#  'about',
#  'python',
#  'and',
#  'machine',
#  'learningBecome',
#  'more',
#  'familiar',
#  'with',
#  'pythongain',
#  'more',
#  'knowledgeGain',
#  'a',
#  'more',
#  'efficient',
#  'way',
#  'of',
#  'handling',
#  'data',
#  'compared',
#  'to',
#  'what',
#  'i',
#  'currently',
#  'knowintermidiat',
#  'pythonLearn',
#  'how',
#  'to',
#  'incorporate',
#  'python',
#  'in',
#  'Machine',
#  'learninglearn',
#  'basic',
#  'data',
#  'science',
#  'skillI',
#  'will',
#  'increase',
#  'my',
#  'basic',
#  'skill',
#  'in',
#  'data',
#  'science',
#  'with',
#  'pythonLearn',
#  'how',
#  'to',
#  'use',
#  'botto',
#  'learn',
#  'about',
#  'python',
#  'in',
#  'data',
#  'sciencejust',
#  'refresh',
#  'on',
#  'fundamentalsto',
#  'do',
#  'well',
#  'in',
#  'machine',
#  'learningKnowledge',
#  'on',
#  'the',
#  'fundamentals',
#  'of',
#  'the',
#  'language',
#  'to',
#  'use',
#  'from',
#  'a',
#  'Data',
#  'Science',
#  'perspectiveTo',
#  'learn',
#  'the',
#  'practical',
#  'use',
#  'of',
#  'data',
#  'science',
#  'and',
#  'machine',
#  'learningI',
#  'expect',
#  'to',
#  'understand',
#  'everything',
#  'related',
#  'to',
#  'this',
#  'class.More',
#  'understand',
#  'about',
#  'python',
#  'for',
#  'data',
#  'scienceLearn',
#  'new',
#  'techniquesNo',
#  'expectationUnderstanding',
#  'Pythonlearn',
#  'and',
#  'gain',
#  'experience',
#  'about',
#  'python',
#  'and',
#  'machine',
#  'learningI',
#  'want',
#  'to',
#  'be',
#  'able',
#  'to',
#  'use',
#  'python',
#  'more',
#  'efficiently.Learning',
#  'more',
#  'about',
#  'using',
#  'python',
#  'for',
#  'data',
#  'science',
#  'purposesTo',
#  'learn',
#  'more',
#  'about',
#  'Python',
#  'in',
#  'Data',
#  'scienceBasic',
#  'PythonHave',
#  'a',
#  'basic',
#  'foundation',
#  'about',
#  'machine',
#  'learninglearning',
#  'some',
#  'basics',
#  'on',
#  'pythonLearn',
#  'Python',
#  'programming',
#  'languageable',
#  'to',
#  'implement',
#  'phyton',
#  'in',
#  'machine',
#  'learningLearn',
#  'more',
#  'about',
#  'real',
#  'world',
#  'python',
#  'applicationsLearn',
#  'something',
#  'newNilTo',
#  'have',
#  'a',
#  'deeper',
#  'understanding',
#  'in',
#  'Python!',
#  'Because',
#  "I've",
#  'only',
#  'learnt',
#  'about',
#  'Python',
#  'but',
#  'now',
#  'how',
#  'it',
#  'can',
#  'be',
#  'used',
#  'in',
#  'Data',
#  'ScienceLearning',
#  'the',
#  'basics',
#  'to',
#  'be',
#  'able',
#  'to',
#  'do',
#  'somethingImproving',
#  'my',
#  'knowledge',
#  'in',
#  'Pythongetting',
#  'to',
#  'know',
#  'more',
#  'about',
#  'machine',
#  'learning',
#  'advanced',
#  'fundamentalsget',
#  'to',
#  'know',
#  'more',
#  'about',
#  'pythonGain',
#  'a',
#  'better',
#  'knowledge',
#  'about',
#  'looping',
#  'after',
#  'the',
#  'class-Know',
#  'more',
#  'about',
#  'Python',
#  'and',
#  'MLunderstand',
#  'how',
#  'to',
#  'use',
#  'loop',
#  'and',
#  'condition',
#  'better',
#  'in',
#  'phytonlearn',
#  'python',
#  'in',
#  'data',
#  'scienceGet',
#  'more',
#  'familiarized',
#  'with',
#  'Python',
#  'writeupslearn',
#  'data',
#  'science',
#  'using',
#  'pythonClear',
#  'notes',
#  'and',
#  'teachinglearn',
#  'the',
#  'fundamentalsusing',
#  'python',
#  'for',
#  'data',
#  'scienceTo',
#  'be',
#  'able',
#  'to',
#  'code',
#  'using',
#  'python',
#  'in',
#  'breeze.My',
#  'expectation',
#  'is',
#  'to',
#  'understand',
#  'more',
#  'about',
#  'python',
#  'and',
#  'data',
#  'science.Know',
#  'more',
#  'about',
#  'PythonMore',
#  'things',
#  'about',
#  'ML.',
#  'More',
#  'data',
#  'processing',
#  'knowledge',
#  'is',
#  'better.Easy',
#  'to',
#  'follow',
#  'instructions',
#  'and',
#  'slidesLearn',
#  'fundamentals',
#  'of',
#  'Python,',
#  'and',
#  'hope',
#  'use',
#  'these',
#  'basics',
#  'to',
#  'prepare',
#  'for',
#  'the',
#  'more',
#  'advanced',
#  'coursesLearn',
#  'more',
#  'about',
#  'data',
#  'sciencelearn',
#  'some',
#  'basics',
#  'about',
#  'Pythonlearn',
#  'how',
#  'to',
#  'detect',
#  'human',
#  'in',
#  'photoI',
#  'hope',
#  'to',
#  'learn',
#  'how',
#  'python',
#  'is',
#  'applied',
#  'in',
#  'data',
#  'scienceLearn',
#  'pythonLearn',
#  'more',
#  'about',
#  'python',
#  'and',
#  'its',
#  'usage',
#  'in',
#  'the',
#  'area',
#  'of',
#  'Data',
#  'science.Learn',
#  'more',
#  'about',
#  'Data',
#  'ScienceCan',
#  'do',
#  'programming',
#  'in',
#  'pythonGain',
#  'technical',
#  'know-how',
#  'on',
#  'using',
#  'libraries',
#  'like',
#  'scikit',
#  'learn',
#  'or',
#  'others',
#  'to',
#  'create',
#  'machine',
#  'learning',
#  'models.NothingLearn',
#  'and',
#  'practice',
#  'new',
#  'knowledgeget',
#  'to',
#  'kow',
#  'python',
#  'data',
#  'science',
#  'betterSomething',
#  'new,',
#  'especially',
#  'for',
#  'ML',
#  'usageAs',
#  'a',
#  'revision',
#  'for',
#  'python',
#  'syntaxLearn',
#  'and',
#  'develop',
#  'something',
#  'newLearn',
#  'things',
#  'useful',
#  'for',
#  'class,',
#  'easy',
#  'to',
#  'followKnowledgenaGet',
#  'some',
#  'exposureLearning',
#  'something',
#  'new',
#  'about',
#  'pythonTo',
#  'learn',
#  'how',
#  'to',
#  'use',
#  'coding',
#  'knowledge',
#  'in',
#  'data',
#  'scienceLearn',
#  'some',
#  'basic',
#  'Python',
#  'skillsMore',
#  'understanding',
#  'and',
#  'able',
#  'to',
#  'adapt',
#  'with',
#  'the',
#  'project',
#  'or',
#  'working',
#  'in',
#  'the',
#  'futureAble',
#  'to',
#  'learn',
#  'something',
#  'newLearn',
#  'basic',
#  'codingKnow',
#  'more',
#  'about',
#  'this',
#  'topicnot',
#  'sure-Have',
#  'a',
#  'deeper',
#  'knowledge',
#  'about',
#  'Python',
#  'and',
#  'able',
#  'to',
#  'utilise',
#  'it',
#  'more',
#  'efficientlyLearning',
#  'more',
#  'indepth',
#  'integration',
#  'of',
#  'machine',
#  'learning',
#  'and',
#  'computer',
#  'vision',
#  'for',
#  'projects',
#  'that',
#  'I',
#  'am',
#  'working',
#  'onto',
#  'improve',
#  'skill',
#  'and',
#  'knowledge',
#  'in',
#  'data',
#  'scienceBetter',
#  'understandingLearn,',
#  'and',
#  'receive',
#  'some',
#  'materialsMore',
#  'python',
#  'skillsLearn',
#  'somethingto',
#  'learn',
#  'more',
#  'about',
#  'the',
#  'usage',
#  'of',
#  'python',
#  'and',
#  'machine',
#  'learning',
#  'as',
#  'im',
#  'interested',
#  'in',
#  'itTo',
#  'learnHow',
#  'to',
#  'build',
#  'an',
#  'image',
#  'classification',
#  'model',
#  'in',
#  'Python?Familiarise',
#  'with',
#  'python',
#  'and',
#  'gain',
#  'some',
#  'basic',
#  'knowledge',
#  'about',
#  'data',
#  'scienceLearn',
#  'anythingTo',
#  'be',
#  'pro',
#  ...]

# %%
def getwordcount(wordList):
  wDic = {}
  for w in wordList:
    #print(w)
    if w in wDic.keys():
      wDic[w] = wDic[w]+1
    else:
      wDic[w] = 1
    #input()
  res = pd.DataFrame()
  res['vocab'] = wDic.keys()
  res['count'] = wDic.values()
  res = res.sort_values(by='count',ascending=False)
  return res

# %%
getwordcount(wordList)
# Out:
#                vocab  count
# 0                 to    145
# 13               and    134
# 5              about    116
# 11              more    113
# 12            python    100
# ..               ...    ...
# 413   learningCreate      1
# 414  Chatbotstudying      1
# 415    fundamentalTo      1
# 117    learningBasic      1
# 814               ds      1
#
# [815 rows x 2 columns]

# %%
# !pip install nltk
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.6/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk) (1.12.0)
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stop_words = set(stopwords.words('english'))
stop_words = [s.lower() for s in stop_words]
filtered_sentence = [w.lower() for w in wordList if not w in stop_words]

# %%
getwordcount(filtered_sentence).iloc[0:50]
# Out:
#              vocab  count
# 8           python    138
# 3             data    122
# 34           learn     66
# 9          machine     51
# 25         science     45
# 24             use     42
# 2        knowledge     36
# 15        learning     31
# 5       understand     28
# 23   understanding     26
# 16           using     23
# 534          numpy     22
# 124    pythonlearn     22
# 45       something     21
# 54               i     20
# 39           basic     19
# 306         pandas     19
# 108            new     17
# 51            able     17
# 20        pythonto     16
# 0             gain     16
# 125         basics     14
# 21             get     14
# 216         better     14
# 76           apply     14
# 196   sciencelearn     13
# 229      scienceto     13
# 213           know     11
# 86         improve     11
# 318         skills     11
# 363           much     11
# 182          skill     10
# 209           used     10
# 29     programming     10
# 42            want      9
# 111           real      9
# 19    fundamentals      9
# 85        familiar      8
# 81            code      8
# 59            hope      8
# 191      practical      7
# 14      experience      7
# 41       learningi      7
# 255           like      7
# 234         things      6
# 77          future      6
# 340    fundamental      6
# 96          coding      6
# 98         pythoni      6
# 56        projects      5

# %%
import matplotlib.pyplot as plt 
from wordcloud import WordCloud, STOPWORDS

wordcloud = WordCloud(max_words=100, background_color="white").generate(textList)
plt.figure(figsize = (16, 16))
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# # Skill

# %%
pythonskill = dat['PythonSkill'].value_counts()
pythonskill.plot.bar()

# %%
datascienceskill = dat['MLSkill'].value_counts()
datascienceskill.plot.bar()

# %% [markdown]
# # Age

# %%
agedat = dat['Age']
agedat = agedat[agedat!='']

# %%
agedat.hist(bins=20)

# %%
dat['Age'].astype('float')
# Out:
# 1      23.0
# 2      25.0
# 3      18.0
# 4      40.0
# 5      23.0
#        ...
# 539    21.0
# 540    30.0
# 541    21.0
# 542    13.0
# 543    22.0
# Name: Age, Length: 543, dtype: float64

# %% [markdown]
# Get age range

# %%
lb = (dat['Age']/5).astype('int')*5 #lower bound
ub = lb + 5 #upper bound
lb = lb.astype('str')
ub = ub.astype('str')
dat['AgeRange'] = lb + '-' + ub
dat
# Out:
#              Timestamp Title  ...                     Fav3 AgeRange
# 1    7/1/2020 15:21:41   Mr.  ...  Computers & Peripherals    20-25
# 2    7/1/2020 15:38:09   Ms.  ...         Food & Beverages    25-30
# 3    7/1/2020 15:38:59   Mr.  ...              Video Games    15-20
# 4    7/1/2020 15:41:46   Ms.  ...  Jewellery & Accessories    40-45
# 5    7/1/2020 15:47:54   Mr.  ...               Men's Wear    20-25
# ..                 ...   ...  ...                      ...      ...
# 539  7/5/2020 16:07:19   Mr.  ...         Food & Beverages    20-25
# 540  7/5/2020 18:04:25   Ms.  ...          Hobbies & Books    30-35
# 541  7/5/2020 20:57:21   Ms.  ...         Mobile & Gadgets    20-25
# 542   7/6/2020 7:43:49   Mr.  ...         Mobile & Gadgets    10-15
# 543   7/6/2020 8:55:18   Mr.  ...         Food & Beverages    20-25
#
# [543 rows x 11 columns]

# %% [markdown]
# # Title

# %%
titledat = dat[(dat['Title']=='Mr.') | (dat['Title']=='Ms.')]['Title'].value_counts()
titledat.plot.bar()

# %% [markdown]
# # Citizen

# %%
citizen = dat['Citizen'].value_counts()
citizen.plot.bar()

# %% [markdown]
# Citizen X Title

# %%
pd.crosstab(dat['Citizen'],dat['Title'])
# Out:
# Title         Mr.  Ms.
# Citizen
# Bangladesh      1    0
# China           1    6
# Hongkong        0    1
# India           1    0
# Indonesia      68   40
# Malaysia       51   72
# Myanmar         1    1
# Philippines    18    9
# Singapore      97   90
# Singapore PR    1    0
# Taiwai         13   20
# Taiwan          3    9
# Thailand       18   10
# Vietnam         6    6

# %%
citizenXtitle = pd.crosstab(dat['Citizen'],dat['Title'],normalize=0)
citizenXtitle
# Out:
# Title              Mr.       Ms.
# Citizen
# Bangladesh    1.000000  0.000000
# China         0.142857  0.857143
# Hongkong      0.000000  1.000000
# India         1.000000  0.000000
# Indonesia     0.629630  0.370370
# Malaysia      0.414634  0.585366
# Myanmar       0.500000  0.500000
# Philippines   0.666667  0.333333
# Singapore     0.518717  0.481283
# Singapore PR  1.000000  0.000000
# Taiwai        0.393939  0.606061
# Taiwan        0.250000  0.750000
# Thailand      0.642857  0.357143
# Vietnam       0.500000  0.500000

# %%
sns.heatmap(citizenXtitle, annot=True)

# %% [markdown]
# Sort before plot makes it look easier

# %%
sns.heatmap(citizenXtitle.sort_values(by='Mr.'),annot=True)

# %% [markdown]
# # Categories

# %%
f1 = dat['Fav1'].value_counts()
f1.plot.bar()

# %%
dat[dat['AgeRange']=='20-25']
# Out:
#              Timestamp Title  ...                     Fav3 AgeRange
# 1    7/1/2020 15:21:41   Mr.  ...  Computers & Peripherals    20-25
# 5    7/1/2020 15:47:54   Mr.  ...               Men's Wear    20-25
# 6    7/1/2020 16:00:57   Ms.  ...         Food & Beverages    20-25
# 7    7/1/2020 16:09:39   Mr.  ...         Food & Beverages    20-25
# 8    7/1/2020 16:10:44   Mr.  ...         Mobile & Gadgets    20-25
# ..                 ...   ...  ...                      ...      ...
# 537  7/5/2020 14:14:42   Ms.  ...          Women's Apparel    20-25
# 538  7/5/2020 14:24:58   Ms.  ...          Women's Apparel    20-25
# 539  7/5/2020 16:07:19   Mr.  ...         Food & Beverages    20-25
# 541  7/5/2020 20:57:21   Ms.  ...         Mobile & Gadgets    20-25
# 543   7/6/2020 8:55:18   Mr.  ...         Food & Beverages    20-25
#
# [313 rows x 11 columns]

# %%
mrdat = dat[dat['Title']=='Mr.']
f1mr = mrdat['Fav1'].value_counts()
f1mr.plot.bar()

# %%
msdat = dat[dat['Title']=='Ms.'].dropna()
f1ms = msdat['Fav1'].value_counts()
f1ms.plot.bar()

# %%
labels = range(18)
sf1 = pd.concat([f1mr,f1ms],axis=1)
sf1
sf1.columns = ['mr','ms']
#sf1
sf1.plot.bar()

# %% [markdown]
# AgeRange X Categories

# %%
pd.crosstab(mrdat['AgeRange'],mrdat['Fav1'])
# Out:
# Fav1      Beauty & Personal Care  Computers & Peripherals  ...  Video Games  Watches
# AgeRange                                                   ...
# 10-15                          0                        1  ...            0        0
# 15-20                          0                       18  ...            8        0
# 20-25                          3                       37  ...           22        2
# 25-30                          1                       18  ...            4        1
# 30-35                          1                        9  ...            1        0
# 35-40                          0                        8  ...            0        0
# 40-45                          0                        0  ...            0        0
# 45-50                          0                        4  ...            0        0
# 50-55                          0                        0  ...            0        0
#
# [9 rows x 8 columns]

# %%
pd.crosstab(mrdat['AgeRange'],mrdat['Fav1'],normalize=1)
# Out:
# Fav1      Beauty & Personal Care  ...   Watches
# AgeRange                          ...
# 10-15                        0.0  ...  0.000000
# 15-20                        0.0  ...  0.000000
# 20-25                        0.6  ...  0.666667
# 25-30                        0.2  ...  0.333333
# 30-35                        0.2  ...  0.000000
# 35-40                        0.0  ...  0.000000
# 40-45                        0.0  ...  0.000000
# 45-50                        0.0  ...  0.000000
# 50-55                        0.0  ...  0.000000
#
# [9 rows x 8 columns]

# %%
mrtab = pd.crosstab(mrdat['AgeRange'],mrdat['Fav1'],normalize=0)
mrtab
# Out:
# Fav1      Beauty & Personal Care  ...   Watches
# AgeRange                          ...
# 10-15                   0.000000  ...  0.000000
# 15-20                   0.000000  ...  0.000000
# 20-25                   0.020690  ...  0.013793
# 25-30                   0.022727  ...  0.022727
# 30-35                   0.058824  ...  0.000000
# 35-40                   0.000000  ...  0.000000
# 40-45                   0.000000  ...  0.000000
# 45-50                   0.000000  ...  0.000000
# 50-55                   0.000000  ...  0.000000
#
# [9 rows x 8 columns]

# %%
sns.heatmap(mrtab, annot=True)

# %%
pd.crosstab(msdat['AgeRange'],msdat['Fav1'])
# Out:
# Fav1      Beauty & Personal Care  ...  Women's Apparel
# AgeRange                          ...
# 0-5                            0  ...                0
# 10-15                          0  ...                0
# 15-20                          8  ...               10
# 20-25                         38  ...               37
# 25-30                          8  ...                3
# 30-35                          2  ...                0
# 35-40                          3  ...                1
# 40-45                          3  ...                0
# 45-50                          0  ...                0
#
# [9 rows x 9 columns]

# %%
mstab = pd.crosstab(msdat['AgeRange'],msdat['Fav1'],normalize=0)
mstab
# Out:
# Fav1      Beauty & Personal Care  ...  Women's Apparel
# AgeRange                          ...
# 0-5                     0.000000  ...         0.000000
# 10-15                   0.000000  ...         0.000000
# 15-20                   0.235294  ...         0.294118
# 20-25                   0.226190  ...         0.220238
# 25-30                   0.235294  ...         0.088235
# 30-35                   0.285714  ...         0.000000
# 35-40                   0.300000  ...         0.100000
# 40-45                   0.600000  ...         0.000000
# 45-50                   0.000000  ...         0.000000
#
# [9 rows x 9 columns]

# %%
sns.heatmap(mstab, annot=True)

# %%
favtab = pd.crosstab(dat['Fav1'],dat['Fav2'])
favtab
# Out:
# Fav2                     Beauty & Personal Care  ...  Women's Apparel
# Fav1                                             ...
# Beauty & Personal Care                        3  ...               19
# Computers & Peripherals                       5  ...                0
# Food & Beverages                             16  ...               12
# Hobbies & Books                              21  ...               12
# Jewellery & Accessories                       2  ...                2
# Men's Wear                                    0  ...                0
# Mobile & Gadgets                              8  ...                3
# Video Games                                   2  ...                0
# Watches                                       1  ...                0
# Women's Apparel                              10  ...                0
#
# [10 rows x 10 columns]

# %%
sns.heatmap(favtab,annot=True)
