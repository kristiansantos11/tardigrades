# %% [markdown]
# ## Import Pandas and use its read_csv function to read CSV files.

# %%
import pandas as pd

poke_df = pd.read_csv('pokemon_data.csv')
poke_df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# ## Reading data in pandas

# %%
## Read first 5 rows of poke_df
print(f"The first 5 rows inside poke_df:")
poke_df.head(5)
# Out:
# The first 5 rows inside poke_df:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
## Read the columns
print(f"The columns inside poke_df: \n")
print(list(poke_df.columns))    # poke_df.columns returns index object with list inside. Type cast it into a list if you want.
# Out:
# The columns inside poke_df:
#
# ['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary']

# %%
## Read each column (reading each row inside name column)
print(f"The rows inside column 'Name' are: \n")
poke_df['Name']
# Out:
# The rows inside column 'Name' are:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
## Read multiple columns
print(f"The rows inside the Name, Type 1 and HP columns: \n")
poke_df[['Name', 'Type 1', 'HP']]
# Out:
# The rows inside the Name, Type 1 and HP columns:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %%
## Read a specific row
print(f"The first row contains the following information:\n")
poke_df.iloc[0]  # returns every data inside that row
# Out:
# The first row contains the following information:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %%
## Read a specific number of rows
print("The rows with row index 1 to row index 3 are as follows:")
poke_df.iloc[1:4]    # Prints out rows with index 1 to 3, 4 and above are excluded from the list
# Out:
# The rows with row index 1 to row index 3 are as follows:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
## Read a specific location
print(f"At the 2nd row index (3rd row), 1st column index (2nd column): {poke_df.iloc[2,1]}")
poke_df.iloc[2,1]  # returns whatever data is inside
# Out:
# At the 2nd row index (3rd row), 1st column index (2nd column): Venusaur
# 'Venusaur'

# %% [markdown]
# ## TIP: Iterating through the dataframe (or dataset or whatever)

# %%
## First way: Using loops to iterate with the help of .iterrows() function

#for index, row in poke_df.iterrows():   # IMPORTANT: Useful if you want a pointer iterating across the dataset.
    #print(index, row)                   # This will print out complete string information across each row
    #print(index, row['Name'])           # This will print out the Name column only (along with their respective index)
    
# Instead of manually iterating through the rows using for loop (for loops are still useful though)
# This is only useful if you want to separate one group of data and appending it to another dataframe or set
# or if you just want to print the specific group inside a column
# You can use multiple conditions inside loc[]
poke_df.loc[poke_df['Type 1'] == "Fire"]
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %% [markdown]
# ## Describing data

# %%
poke_df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %% [markdown]
# ## Sorting data

# %%
# Sorting the data frame using Names in ascending order
poke_df = poke_df.sort_values('Name')
poke_df

# Sorting the data frame using Names in descending order
poke_df = poke_df.sort_values('Name', ascending=False)
poke_df

# Sorting the data frame using multiple columns, with the Type 1 column being
# in ascending order while the HP being in descending order.
# IMPORTANT: This code is useful for categorical columns (or those with foreign key columns)
poke_df = poke_df.sort_values(['Type 1', 'HP'], ascending=[True, False])
poke_df
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 734  666                 Vivillon    Bug    Flying  80      52       50
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 231  214                Heracross    Bug  Fighting  80     125       75
# ..   ...                      ...    ...       ...  ..     ...      ...
# 97    90                 Shellder  Water       NaN  30      65      100
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ## Making changes to the data

# %%
# One way of adding columns and adding the result to
# a new column. This is the safer way.

poke_df['Total'] = (poke_df['HP'] + poke_df['Attack'] + poke_df['Defense'] + poke_df['Sp. Atk'] + 
                    poke_df['Sp. Def'] + poke_df['Speed'])
poke_df.head(5)


# Another way of adding columns and adding the result to
# a new column. WARNING: ITS DANGEROUS. USE AT YOUR OWN RISK

# Axis = 1: Horizontally; Row
# Axis = 0: Vertically; Column
'''
poke_df['Total'] = poke_df.iloc[:, 4:10].sum(axis=1)
'''
# One way of Reordering columns. USE AT OWN RISK
'''
cols_reorder = list(poke_df.columns.values)
poke_df = poke_df[cols_reorder[0:4] + cols_reorder[5:11] + [cols_reorder[4]] +
                 cols_reorder[11:13]]
'''
# A better way of Reordering columns.
poke_df = poke_df[['#', 'Name', 'Type 1','Type 2', 'HP', 'Attack', 'Defense',
                  'Sp. Atk', 'Sp. Def', 'Speed', 'Total', 
                  'Generation', 'Legendary']]

poke_df.head(5)
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 734  666                 Vivillon    Bug    Flying  80      52       50
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 231  214                Heracross    Bug  Fighting  80     125       75
#
#      Sp. Atk  Sp. Def  Speed  Total  Generation  Legendary
# 520      116       56     95    515           4      False
# 698      135      105    100    550           5      False
# 734       90       50     89    411           6      False
# 232       40      105     75    600           2      False
# 231       40       95     85    500           2      False

# %% [markdown]
# # Dropping a column

# %%
# If you wanna drop a specific column
'''
poke_df = poke_df.drop(columns=['Total'])
poke_df.head(5)
'''
# Out:
# "\npoke_df = poke_df.drop(columns=['Total'])\npoke_df.head(5)\n"

# %% [markdown]
# ## Export into desired format

# %%
# This exports into .csv (Comma Separated Values) format WITH INDEX.
'''
poke_df.to_csv('modified-poke-data.csv')
'''
# Pass an index=False parameter inside the index inside the exported file
'''
poke_df.to_csv('modified-poke-data.csv', index=False)
'''
# Pass a sep='\t' separator parameter inside if you want the csv file
# to be separated by tabs instead of commas
'''
poke_df.to_csv('modified-poke-data.csv', index=False, sep='\t')
'''
# Same goes for the txt format
'''
poke_df.to_csv('modified-poke-data.txt', index=False, sep='\t')
'''
# Exporting into xlsx (Excel) format.
'''
poke_df.to_excel('modified-poke-data.xlsx', index=False)
'''

# %% [markdown]
# # Filtering Data

# %%
# Output only the rows with type 1 == Grass
poke_df.loc[poke_df['Type 1'] == 'Grass']
# Out:
#        #               Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 741  673             Gogoat  Grass     NaN  123     100       62       97
# 652  591          Amoonguss  Grass  Poison  114      85       70       85
# 516  465          Tangrowth  Grass     NaN  100     100      125      110
# 551  492   ShayminSky Forme  Grass  Flying  100     103       75      120
# 550  492  ShayminLand Forme  Grass     NaN  100     100      100      100
# ..   ...                ...    ...     ...  ...     ...      ...      ...
# 296  273             Seedot  Grass     NaN   40      40       50       30
# 606  546           Cottonee  Grass   Fairy   40      27       60       37
# 451  406              Budew  Grass  Poison   40      30       35       50
# 202  187             Hoppip  Grass  Flying   35      35       40       35
# 206  191            Sunkern  Grass     NaN   30      30       30       30
#
#      Sp. Def  Speed  Total  Generation  Legendary
# ...

# %%
# Output rows with Type 1 grass and type 2 poison
poke_df.loc[(poke_df['Type 1'] == 'Grass') &
            (poke_df['Type 2'] == 'Poison') &
           (poke_df['HP'] > 70)]
# Make sure the 2 conditions are separated by parentheses
# Also the conditional operators inside pandas parameters should be:
# & for and; | for or
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 652  591              Amoonguss  Grass  Poison  114      85       70       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 50    45              Vileplume  Grass  Poison   75      80       85      110
#
#      Sp. Def  Speed  Total  Generation  Legendary
# 652       80     30    464           5      False
# 77        70     70    490           1      False
# 3        120     80    625           1      False
# 2        100     80    525           1      False
# 50        90     50    490           1      False

# %%
# Copy these values to another dataframe:
grass_poison_hp70 = poke_df.loc[(poke_df['Type 1'] == 'Grass') &
            (poke_df['Type 2'] == 'Poison') &
           (poke_df['HP'] > 70)]

grass_poison_hp70
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 652  591              Amoonguss  Grass  Poison  114      85       70       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 50    45              Vileplume  Grass  Poison   75      80       85      110
#
#      Sp. Def  Speed  Total  Generation  Legendary
# 652       80     30    464           5      False
# 77        70     70    490           1      False
# 3        120     80    625           1      False
# 2        100     80    525           1      False
# 50        90     50    490           1      False

# %% [markdown]
# However, the index of the new dataframe are preserved from its parent dataframe.

# %%
# To reset index
grass_poison_hp70.reset_index(drop=True, inplace=True)
grass_poison_hp70
# Out:
#      #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0  591              Amoonguss  Grass  Poison  114      85       70       85
# 1   71             Victreebel  Grass  Poison   80     105       65      100
# 2    3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 3    3               Venusaur  Grass  Poison   80      82       83      100
# 4   45              Vileplume  Grass  Poison   75      80       85      110
#
#    Sp. Def  Speed  Total  Generation  Legendary
# 0       80     30    464           5      False
# 1       70     70    490           1      False
# 2      120     80    625           1      False
# 3      100     80    525           1      False
# 4       90     50    490           1      False

# %%
# You can export the new dataframe into a csv file as a checkpoint
grass_poison_hp70.to_csv('grass-poison-hp70.csv', index=False)

# %% [markdown]
# Returning to the poke_df dataframe:

# %%
# If you want to retain only the 'mega' pokemons:
poke_df.loc[poke_df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 232  214    HeracrossMega Heracross       Bug  Fighting   80     185      115
# 229  212          ScizorMega Scizor       Bug     Steel   70     150      140
# 137  127          PinsirMega Pinsir       Bug    Flying   65     155      120
# 19    15      BeedrillMega Beedrill       Bug    Poison   65     150       40
# 248  229      HoundoomMega Houndoom      Dark      Fire   75      90       90
# 393  359            AbsolMega Absol      Dark       NaN   65     150       60
# 327  302        SableyeMega Sableye      Dark     Ghost   50      85      125
# 494  445      GarchompMega Garchomp    Dragon    Ground  108     170      115
# 426  384      RayquazaMega Rayquaza    Dragon    Flying  105     180      100
# 409  373    SalamenceMega Salamence    Dragon    Flying   95     145      130
# 420  381          LatiosMega Latios    Dragon   Psychic   80     130      100
# ...

# %%
# If you want to filter out 'Mega' name:
poke_df.loc[~poke_df['Name'].str.contains('Mega')]
# ~ (tilde) is a NOT conditional operator
# Out:
#        #       Name Type 1    Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 520  469    Yanmega    Bug    Flying  86      76       86      116       56
# 698  637  Volcarona    Bug      Fire  85      60       65      135      105
# 734  666   Vivillon    Bug    Flying  80      52       50       90       50
# 231  214  Heracross    Bug  Fighting  80     125       75       40       95
# 678  617   Accelgor    Bug       NaN  80      70       40      100       60
# ..   ...        ...    ...       ...  ..     ...      ...      ...      ...
# 97    90   Shellder  Water       NaN  30      65      100       45       25
# 106   98     Krabby  Water       NaN  30     105       90       25       25
# 125  116     Horsea  Water       NaN  30      40       70       70       25
# 139  129   Magikarp  Water       NaN  20      10       55       15       20
# 381  349     Feebas  Water       NaN  20      15       20       10       55
#
#      Speed  Total  Generation  Legendary
# ...

# %%
# If you want to get the fire and grass type pokemons only
# You can use regex:
import re

poke_df.loc[poke_df['Type 1'].str.contains('fire|grass', flags=re.I, regex=True)]
# flags=re.I means ignore capitalization
# regex=True means you enable regex symbols/functions inside the contains function
# Out:
#        #                     Name Type 1    Type 2   HP  Attack  Defense  \
# 263  244                    Entei   Fire       NaN  115     115       85
# 559  500                   Emboar   Fire  Fighting  110     123       65
# 270  250                    Ho-oh   Fire    Flying  106     130       90
# 616  555       DarmanitanZen Mode   Fire   Psychic  105      30      105
# 615  555  DarmanitanStandard Mode   Fire       NaN  105     140       55
# ..   ...                      ...    ...       ...  ...     ...      ...
# 296  273                   Seedot  Grass       NaN   40      40       50
# 606  546                 Cottonee  Grass     Fairy   40      27       60
# 451  406                    Budew  Grass    Poison   40      30       35
# 202  187                   Hoppip  Grass    Flying   35      35       40
# 206  191                  Sunkern  Grass       NaN   30      30       30
#
#      Sp. Atk  Sp. Def  Speed  Total  Generation  Legendary
# ...

# %%
# If you want to find out all the pokemon names that contain the
# string sequence: "pi"
poke_df.loc[poke_df['Name'].str.contains('pi[a-z]*', flags=re.I, regex=True)]
# [a-z] range of letters from a to z
# asterisk (*) at the end means whatever sequence of [a-z] from zero to
# infinite amount of characters
# Out:
#        #                     Name    Type 1    Type 2   HP  Attack  Defense  \
# 463  416                Vespiquen       Bug    Flying   70      80      102
# 137  127        PinsirMega Pinsir       Bug    Flying   65     155      120
# 136  127                   Pinsir       Bug       NaN   65     125      100
# 219  204                   Pineco       Bug       NaN   50      65       90
# 13    10                 Caterpie       Bug       NaN   45      30       35
# 181  167                 Spinarak       Bug    Poison   40      60       40
# 30    25                  Pikachu  Electric       NaN   35      55       40
# 186  172                    Pichu  Electric       NaN   20      40       15
# 189  175                   Togepi     Fairy       NaN   35      20       65
# 558  499                  Pignite      Fire  Fighting   90      93       55
# 557  498                    Tepig      Fire       NaN   65      63       45
# ...

# %%
# If you want to find every pokemon that has a name that starts with
# 'pi'
poke_df.loc[poke_df['Name'].str.contains('^pi[a-z]*', flags=re.I, regex=True)]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 136  127               Pinsir       Bug       NaN   65     125      100
# 219  204               Pineco       Bug       NaN   50      65       90
# 30    25              Pikachu  Electric       NaN   35      55       40
# 186  172                Pichu  Electric       NaN   20      40       15
# 558  499              Pignite      Fire  Fighting   90      93       55
# 239  221            Piloswine       Ice    Ground  100     100       80
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 578  519               Pidove    Normal    Flying   50      55       50
# 20    16               Pidgey    Normal    Flying   40      45       40
# ...

# %% [markdown]
# ## Conditional Changes

# %% [markdown]
# Change every existence of the word 'Fire' inside column Type 1 into 'Flamer'

# %%
poke_df.loc[poke_df['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'
poke_df.loc[poke_df['Type 1'] == 'Flamer']
# Out:
#        #                       Name  Type 1    Type 2   HP  Attack  Defense  \
# 263  244                      Entei  Flamer       NaN  115     115       85
# 559  500                     Emboar  Flamer  Fighting  110     123       65
# 270  250                      Ho-oh  Flamer    Flying  106     130       90
# 616  555         DarmanitanZen Mode  Flamer   Psychic  105      30      105
# 615  555    DarmanitanStandard Mode  Flamer       NaN  105     140       55
# 542  485                    Heatran  Flamer     Steel   91      90      106
# 558  499                    Pignite  Flamer  Fighting   90      93       55
# 158  146                    Moltres  Flamer    Flying   90     100       90
# 64    59                   Arcanine  Flamer       NaN   90     110       80
# 736  668                     Pyroar  Flamer    Normal   86      68       72
# 692  631                    Heatmor  Flamer       NaN   85      97       66
# ...

# %% [markdown]
# If you want to change 'Flamer' back to 'Fire'

# %%
poke_df.loc[poke_df['Type 1'] == 'Flamer', 'Type 1'] = 'Fire'
poke_df.loc[poke_df['Type 1'] == 'Fire']
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 263  244                      Entei   Fire       NaN  115     115       85
# 559  500                     Emboar   Fire  Fighting  110     123       65
# 270  250                      Ho-oh   Fire    Flying  106     130       90
# 616  555         DarmanitanZen Mode   Fire   Psychic  105      30      105
# 615  555    DarmanitanStandard Mode   Fire       NaN  105     140       55
# 542  485                    Heatran   Fire     Steel   91      90      106
# 558  499                    Pignite   Fire  Fighting   90      93       55
# 158  146                    Moltres   Fire    Flying   90     100       90
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 736  668                     Pyroar   Fire    Normal   86      68       72
# 692  631                    Heatmor   Fire       NaN   85      97       66
# ...

# %% [markdown]
# If you want to change all Fire pokemon Legendary status to True
# Set up a test dataframe since we don't want to screw up the actual dataframe

# %%
test_df = poke_df
test_df.loc[test_df['Type 1'] == 'Fire', 'Legendary'] = True
test_df.loc[test_df['Type 1'] == 'Fire']
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 263  244                      Entei   Fire       NaN  115     115       85
# 559  500                     Emboar   Fire  Fighting  110     123       65
# 270  250                      Ho-oh   Fire    Flying  106     130       90
# 616  555         DarmanitanZen Mode   Fire   Psychic  105      30      105
# 615  555    DarmanitanStandard Mode   Fire       NaN  105     140       55
# 542  485                    Heatran   Fire     Steel   91      90      106
# 558  499                    Pignite   Fire  Fighting   90      93       55
# 158  146                    Moltres   Fire    Flying   90     100       90
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 736  668                     Pyroar   Fire    Normal   86      68       72
# 692  631                    Heatmor   Fire       NaN   85      97       66
# ...

# %%
poke_df = pd.read_csv('modified-poke-data.csv')    # Reset the test_df
test_df = poke_df

# %% [markdown]
# If you want to change the legendary status and generation number of all pokemon with total stat number of above 500 into 'TEST VALUE'

# %%
test_df.loc[test_df['Total'] > 500, ['Generation', 'Legendary']] = 'TEST VALUE'
test_df.loc[test_df['Legendary'] == 'TEST VALUE']
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 717  649                 Genesect    Bug     Steel  71     120       95
# 229  212        ScizorMega Scizor    Bug     Steel  70     150      140
# ..   ...                      ...    ...       ...  ..     ...      ...
# 249  230                  Kingdra  Water    Dragon  75      95       95
# 726  658                 Greninja  Water      Dark  72      95       67
# 349  319    SharpedoMega Sharpedo  Water      Dark  70     140       70
# 130  121                  Starmie  Water   Psychic  60      75       85
# 98    91                 Cloyster  Water       Ice  50      95      180
#
#      Sp. Atk  Sp. Def  Speed  Total  Generation   Legendary
# ...

# %% [markdown]
# If you want to change the generation and legendary value of every pokemon with total stat number of above 500 into:
# Test 1 for Generation column
# Test 2 for Legendary column

# %%
test_df.loc[test_df['Total'] > 500, ['Generation', 'Legendary']] = ['Test 1','Test 2']
test_df.loc[test_df['Legendary'] == 'Test 2']
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 717  649                 Genesect    Bug     Steel  71     120       95
# 229  212        ScizorMega Scizor    Bug     Steel  70     150      140
# ..   ...                      ...    ...       ...  ..     ...      ...
# 249  230                  Kingdra  Water    Dragon  75      95       95
# 726  658                 Greninja  Water      Dark  72      95       67
# 349  319    SharpedoMega Sharpedo  Water      Dark  70     140       70
# 130  121                  Starmie  Water   Psychic  60      75       85
# 98    91                 Cloyster  Water       Ice  50      95      180
#
#      Sp. Atk  Sp. Def  Speed  Total Generation Legendary
# ...

# %%
poke_df = pd.read_csv('modified-poke-data.csv')    # Reset the test_df
test_df = poke_df

# %% [markdown]
# ## Aggregate Statistics (groupby function)
# poke_df is a dataframe. You can group it accordingly using groupby('column_name') function. If you want to group it according to multiple columns, use DataFrame.groupby(['column_name1','column_name2'])

# %% [markdown]
# Grouping by Type 1 and finding the mean of each type 1 then sorting their values by Defense in descending order to find out which type of pokemon has the highest amount of Defense

# %%
poke_df.groupby(['Type 1']).mean().sort_values('Defense', ascending=False)
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Steel     442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Rock      392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Water     303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# Ice       423.541667  72.000000   72.750000   71.416667  77.541667  76.291667
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# Bug       334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Poison    251.785714  67.250000   74.678571   68.821429  60.428571  64.392857
# ...

# %% [markdown]
# Establishing a count column and grouping by Type 1 and finding the total number of pokemons inside each Type 1

# %%
poke_df['count'] = 1
poke_df.groupby(['Type 1']).count()['count']
# It does not count rows with NaN (null type values)
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %% [markdown]
# If you want to group it by multiple columns:

# %%
poke_df.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64
